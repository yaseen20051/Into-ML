# %% [markdown]
# Importing pandas

# %%
import pandas as pd

# %% [markdown]
# Pandas version

# %%
print(pd.__version__)
# Out:
# 2.2.3

# %% [markdown]
# Series

# %%
data = [100,102,104]
series = pd.Series(data)
series
# Out:
# 0    100
# 1    102
# 2    104
# dtype: int64
