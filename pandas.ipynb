# %% [markdown]
# Importing pandas

# %%
import pandas as pd

# %% [markdown]
# Pandas version

# %%
print(pd.__version__)
# Out:
# 2.2.3

# %% [markdown]
# Series

# %%
from pandas import Series 

### Different Datatypes 

int_data = [100,102,104]
int_series = pd.Series(int_data)

float_data = [10.5,20.6,11.5]
float_series = pd.Series(float_data)

object_data = ["Y","a","s"]
object_series = pd.Series(object_data)

bool_data= [True,False]
bool_series = pd.Series(bool_data)

print(f"int datatype : \n{int_series}\n\nfloat datatype : \n{float_series}\n\nobject datatype\n{object_series}\n\nbool datatype\n\n{bool_series}")

### Changing Index  

data = [100,102,104]

changed_labels = Series(data,index = ["User 1","User 2","User 3"])
changed_labels

### loc property 

        ## locate using label
value_user = changed_labels.loc["User 1"]
print(f"\nValue of User 1 (label located)= ${value_user}")

        ## locate using index (staring from zero)
index_located_user_value = changed_labels.iloc[0]
print(f"Value of User 1 (index located)= ${index_located_user_value}")

        ## Changing label
last_value = value_user
changed_labels.loc["User 1"] = 9032
value_user = changed_labels.loc["User 1"]
print(f"\nlast value of user 1 id = {last_value}\ncurrent value after changing using the loc property = {value_user} \n")

        ## filter by value 
prices = [150.5,100,50,20,260,330,550,120]
series_prices = Series(prices,index=["item 1","item 2","item 3","item 4","item 5","item 6","item 7","item 8"])
sum = 0
avg = 0
for price in prices:
    sum = sum + price
avg = sum / len(prices)
print(series_prices[series_prices>avg],"\n")
        ## using dictonary
calories = {"Day 1": 1750, "Day 2":2100,"Day 3":1600} 
## keys will be the labels so no need to insert indeces or labels 
series_calories  = Series(calories)  
print(series_calories)

series_calories.loc["Day 2"] -= 200
print(series_calories.loc["Day 2"],"\n")
print(series_calories.iloc[2],"\n")

print("Cheated days")
print(series_calories[series_calories>1700])
# Out:
# int datatype :
# 0    100
# 1    102
# 2    104
# dtype: int64
#
# float datatype :
# 0    10.5
# 1    20.6
# 2    11.5
# dtype: float64
#
# object datatype
# 0    Y
# 1    a
# 2    s
# dtype: object
#
# bool datatype
#
# 0     True
# 1    False
# dtype: bool
#
# Value of User 1 (label located)= $100
# Value of User 1 (index located)= $100
#
# last value of user 1 id = 100
# current value after changing using the loc property = 9032
#
# item 5    260.0
# item 6    330.0
# item 7    550.0
# dtype: float64
#
# Day 1    1750
# Day 2    2100
# Day 3    1600
# dtype: int64
# 1900
#
# 1600
#
# Cheated days
# Day 1    1750
# Day 2    1900
# dtype: int64

# %% [markdown]
# DataFrames

# %%
from pandas import DataFrame 

data = {
        "Name":["Spongebob","Patrick","Squidward"],
        "Age":[30,50,35]
    }
df = DataFrame(data)
print(df,"\n")

### same manipulation as the series 

    ## changing labels
df = DataFrame(data,index=["Employee 1","Employee 2","Employee 3"])
print(df,"\n")
    ## loc property by (locate by label =)
print(df.loc["Employee 2"],"\n")
    ## iloc property (locate by index)
print(df.iloc[2],"\n")
    ## filtering by vaule and Accessing a specific feature 
print(df[df["Age"]>30],"\n")

### Adding a new columns
df["Job"] = ["Cook","N/A","Cashier"]
print(df,"\n")
### Adding a new row 
        ## new row = pd.DataFrame([{"feature 1":value,"feature 2":value},{second row (second training example )}])
new_row = DataFrame([{"Name":"Sandy","Age":25,"Job":"Scientist"},{"Name":"Yaseen","Age":20,"Job":"ML Engineer"}],index=["Employee 4","Employee 5"])
# DONT FORGET TO CONCATENATE THE NEW RULE OR THE NEW EXAMPLES
df = pd.concat([df,new_row])
print(df,"\n")
    ## other way to add a row (unsuccessful) different examples must be added independently from eachother 
# new_row = DataFrame([{
#                         "Name":["Yahia","Salem"],
#                         "Age":[18,36],
#                         "Job":["Student","Manger"]
#                     }])
# df = pd.concat([df,new_row])
# print(df,"\n")
# Out:
#         Name  Age
# 0  Spongebob   30
# 1    Patrick   50
# 2  Squidward   35
#
#                  Name  Age
# Employee 1  Spongebob   30
# Employee 2    Patrick   50
# Employee 3  Squidward   35
#
# Name    Patrick
# Age          50
# Name: Employee 2, dtype: object
#
# Name    Squidward
# Age            35
# Name: Employee 3, dtype: object
#
#                  Name  Age
# Employee 2    Patrick   50
# Employee 3  Squidward   35
#
#                  Name  Age      Job
# Employee 1  Spongebob   30     Cook
# Employee 2    Patrick   50      N/A
# Employee 3  Squidward   35  Cashier
#
#                  Name  Age          Job
# Employee 1  Spongebob   30         Cook
# Employee 2    Patrick   50          N/A
# Employee 3  Squidward   35      Cashier
# Employee 4      Sandy   25    Scientist
# Employee 5     Yaseen   20  ML Engineer

# %% [markdown]
# Importing CSV

# %%
df = pd.read_csv("data.csv")
### print truncated data 
print(df)
### print  everything 
print(df.to_string())
# Out:
#       No        Name    Type1   Type2  Height  Weight  Legendary
# 0      1   Bulbasaur    Grass  Poison     0.7     6.9          0
# 1      2     Ivysaur    Grass  Poison     1.0    13.0          0
# 2      3    Venusaur    Grass  Poison     2.0   100.0          0
# 3      4  Charmander     Fire     NaN     0.6     8.5          0
# 4      5  Charmeleon     Fire     NaN     1.1    19.0          0
# ..   ...         ...      ...     ...     ...     ...        ...
# 145  146     Moltres     Fire  Flying     2.0    60.0          1
# 146  147     Dratini   Dragon     NaN     1.8     3.3          0
# 147  148   Dragonair   Dragon     NaN     4.0    16.5          0
# 148  149   Dragonite   Dragon  Flying     2.2   210.0          0
# 149  150      Mewtwo  Psychic     NaN     2.0   122.0          1
#
# [150 rows x 7 columns]
#       No        Name     Type1     Type2  Height  Weight  Legendary
# 0      1   Bulbasaur     Grass    Poison     0.7     6.9          0
# ...

# %% [markdown]
# Selection Techniques

# %%
df = pd.read_csv("data.csv")

### Selection by column 
name_column =  df["Name"]
        ## print trauncated value 
print(name_column) ### output is a series 
        ## print all values 
print(name_column.to_string())

# print(df["Height"].to_string())

# print(df["Weight"].to_string())
        ## Select Multiple columns 
print(df[["Name","Height","Weight"]])

### Selection by rows 
print(df.loc[0])
# Out:
# 0       Bulbasaur
# 1         Ivysaur
# 2        Venusaur
# 3      Charmander
# 4      Charmeleon
#           ...
# 145       Moltres
# 146       Dratini
# 147     Dragonair
# 148     Dragonite
# 149        Mewtwo
# Name: Name, Length: 150, dtype: object
# 0       Bulbasaur
# 1         Ivysaur
# 2        Venusaur
# 3      Charmander
# 4      Charmeleon
# 5       Charizard
# 6        Squirtle
# 7       Wartortle
# 8       Blastoise
# 9        Caterpie
# 10        Metapod
# 11     Butterfree
# 12         Weedle
# 13         Kakuna
# 14       Beedrill
# 15         Pidgey
# 16      Pidgeotto
# 17        Pidgeot
# 18        Rattata
# 19       Raticate
# 20        Spearow
# 21         Fearow
# 22          Ekans
# 23          Arbok
# 24        Pikachu
# 25         Raichu
# 26      Sandshrew
# 27      Sandslash
# 28       Nidoran♀
# 29       Nidorina
# 30      Nidoqueen
# 31       Nidoran♂
# 32       Nidorino
# 33       Nidoking
# 34       Clefairy
# 35       Clefable
# 36         Vulpix
# ...

# %%
# print(df.loc["Bulbasaur"])
## to get the row of a specific example we need 
df = pd.read_csv("data.csv",index_col="Name")
print(df)
print(df.loc["Bulbasaur"],"\n")
        ### select specific columns
print(df.loc["Bulbasaur":"Venusaur",["Height","Weight"]],"\n")
        ### using iloc 
print(df.iloc[0:3,3:5],"\n")
# Out:
#              No    Type1   Type2  Height  Weight  Legendary
# Name
# Bulbasaur     1    Grass  Poison     0.7     6.9          0
# Ivysaur       2    Grass  Poison     1.0    13.0          0
# Venusaur      3    Grass  Poison     2.0   100.0          0
# Charmander    4     Fire     NaN     0.6     8.5          0
# Charmeleon    5     Fire     NaN     1.1    19.0          0
# ...         ...      ...     ...     ...     ...        ...
# Moltres     146     Fire  Flying     2.0    60.0          1
# Dratini     147   Dragon     NaN     1.8     3.3          0
# Dragonair   148   Dragon     NaN     4.0    16.5          0
# Dragonite   149   Dragon  Flying     2.2   210.0          0
# Mewtwo      150  Psychic     NaN     2.0   122.0          1
#
# [150 rows x 6 columns]
# No                1
# Type1         Grass
# Type2        Poison
# Height          0.7
# Weight          6.9
# Legendary         0
# Name: Bulbasaur, dtype: object
#
#            Height  Weight
# Name
# ...
